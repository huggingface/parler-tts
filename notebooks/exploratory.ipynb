# %% [markdown]
# ## Notebook to explore fine-tuned models

# %%
from parler_tts import ParlerTTSForConditionalGeneration
from transformers import AutoTokenizer
import torch

device = "cuda:0" if torch.cuda.is_available() else "cpu"

PRETRAINED_MODEL_NAME = "parler-tts/parler_tts_mini_v0.1"
FINETUNED_MODEL_NAME = "skbose/parler-tts-mini-v1-Jenny-colab"

model_name = FINETUNED_MODEL_NAME

model = ParlerTTSForConditionalGeneration.from_pretrained(model_name, torch_dtype=torch.float16).to(device)
tokenizer = AutoTokenizer.from_pretrained(PRETRAINED_MODEL_NAME)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from parler_tts import ParlerTTSForConditionalGeneration
#       2 from transformers import AutoTokenizer
#       3 import torch
#
# ModuleNotFoundError: No module named 'parler_tts'

# %%
# check the device
print(device)
# Out:
# cuda:0

# %%
# prompt = "Hey, how are you doing today? It is a bright sunny day today!"
prompt = "Mai ek udta robot hu"
description = "'Jenny delivers her words quite expressively, in a very confined sounding environment with clear audio quality. She speaks slowly.'"

input_ids = tokenizer(description, return_tensors="pt").input_ids.to(device)
prompt_input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(device)

generation = model.generate(input_ids=input_ids, prompt_input_ids=prompt_input_ids)
audio_arr = generation.cpu().numpy().squeeze()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 prompt = "Mai ek udta robot hu"
#       3 description = "'Jenny delivers her words quite expressively, in a very confined sounding environment with clear audio quality. She speaks slowly.'"
# ----> 5 input_ids = tokenizer(description, return_tensors="pt").input_ids.to(device)
#       6 prompt_input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(device)
#       8 generation = model.generate(input_ids=input_ids, prompt_input_ids=prompt_input_ids)
#
# NameError: name 'tokenizer' is not defined

# %%
# Run the audio
from IPython.display import Audio
Audio(audio_arr, rate=model.config.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
